# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold">1. Importing all the necessary Libraries.</span>

# %%
# Importing all the necessary libraries
# Data wrangling and Statistical testing modules
import pandas as pd
import numpy as np
# import statsmodels

# import os

# Data visualization modules
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go

# Suppressing warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold">2. Importing and reading the dataset.</span>

# %%
df_allchsalesunits = pd.read_excel('Data.xlsx', sheet_name= 'All Channel Sales Units')
df_allchsalesvol = pd.read_excel('Data.xlsx', sheet_name= 'All Channel Sales Volume')
df_classification = pd.read_excel('Data.xlsx', sheet_name= 'Classification')
df_company = pd.read_excel('Data.xlsx', sheet_name= 'Company')
df_cogs = pd.read_excel('Data.xlsx', sheet_name= 'COGS')
df_line = pd.read_excel('Data.xlsx', sheet_name= 'Line')
df_oos_sku = pd.read_excel('Data.xlsx', sheet_name= 'OOS Sku')
df_region = pd.read_excel('Data.xlsx', sheet_name= 'Region')
df_sku_region = pd.read_excel('Data.xlsx', sheet_name= 'Sku Region')
df_sku = pd.read_excel('Data.xlsx', sheet_name= 'Sku')

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 22px; font-weight: Bold">Data Quality Checks:</span>
#
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.1. `All Channel Sales Units` table:</span>

# %%
df_allchsalesunits.sample(25)
# Out:
#        Year    Channel                              Sku  \
# 62657  2018  CHANNEL 1                    MED-PEARL-EYE
# 31523  2018  CHANNEL 2        TSN-DP-POWDER-TRAVEL-GIFT
# 50978  2019  CHANNEL 6                  INDG-TOUMEI-DUO
# 42040  2017  CHANNEL 6                CRTD-SAMURAI-CUFF
# 32188  2017  CHANNEL 7               BR-SERUM-TRAVEL-XX
# 6727   2018  CHANNEL 3                      OILY-RITUAL
# 12260  2019  CHANNEL 3             SILK-CLOTH-TRIO-OILY
# 425    2017  CHANNEL 3                     CL-POWDER-PK
# 56694  2017  CHANNEL 1  TSN-HYDRATION-SERUM-TRAVEL-GIFT
# 64637  2019  CHANNEL 1                     GT-KYOTO-DUO
# 51562  2019  CHANNEL 6                    PC-OIL-PM-LOY
# 64219  2019  CHANNEL 1                  ESSENCE-SAMPLER
# 7986   2018  CHANNEL 3                    VIOLET-C-MASK
# 60076  2018  CHANNEL 1                       PAPER-BAGS
# 33887  2018  CHANNEL 7        AGELESS-PLUMP-PROTECT-SET
# 18855  2017  CHANNEL 4        SILK-CLOTH-TRIO-SENSITIVE
# ...

# %%
df_allchsalesunits.info(verbose=True)
# there are NULL/NaN values in the `Merged Sku` column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70422 entries, 0 to 70421
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        70422 non-null  int64
#  1   Channel     70422 non-null  object
#  2   Sku         70422 non-null  object
#  3   Merged Sku  70398 non-null  object
#  4   Month       70422 non-null  object
#  5   Units       70422 non-null  float64
#  6   Brand_Flag  70422 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 3.8+ MB

# %%
print('Detailed information for all the columns: \n')
for cols in df_allchsalesunits.columns:
    print(f'{cols}:')
    print(f'{df_allchsalesunits[cols].value_counts()}\n')
# Out:
# Detailed information for all the columns:
#
# Year:
# 2018    27024
# 2019    24360
# 2017    19038
# Name: Year, dtype: int64
#
# Channel:
# CHANNEL 1    16152
# CHANNEL 3    14544
# CHANNEL 6    11808
# CHANNEL 4    11724
# CHANNEL 7     9504
# CHANNEL 2     4374
# CHANNEL 5     1392
# CHANNEL 8      924
# Name: Channel, dtype: int64
#
# Sku:
# SILK-CREAM-V2                         252
# HYDRATION-SERUM                       252
# PC-OIL                                252
# SERUM-EYE                             252
# GOLDSPUN-LIP-BALM                     252
#                                      ...
# CHANNEL 3-BEAUTY-OIL-DUO-A353490       12
# CHANNEL 3-INDG-POLISH-A344555(851)     12
# CHANNEL 3-PEARL-MED-A342905-849        12
# CHANNEL 3-HD18-A352980                 12
# PEONY-LIP                              12
# Name: Sku, Length: 657, dtype: int64
#
# Merged Sku:
#                                        19938
# SILK-CREAM-V2                            450
# ...

# %%
# Checking for duplicates in the table:
print(f'Total no. of Duplicates in the Table: \
{len(df_allchsalesunits)-len(df_allchsalesunits.drop_duplicates())}')
# Out:
# Total no. of Duplicates in the Table: 0

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.2. `All Channel Sales Volume` table</span>

# %%
df_allchsalesvol
# Out:
#        Year    Channel               Sku Merged Sku Month  Volume Brand_Flag
# 0      2017  CHANNEL 3  7-DAY-BETA-CARDS              Jan     0.0        ABC
# 1      2017  CHANNEL 3  7-DAY-BETA-CARDS              Feb     0.0        ABC
# 2      2017  CHANNEL 3  7-DAY-BETA-CARDS              Mar     0.0        ABC
# 3      2017  CHANNEL 3  7-DAY-BETA-CARDS              Apr     0.0        ABC
# 4      2017  CHANNEL 3  7-DAY-BETA-CARDS              May     0.0        ABC
# ...     ...        ...               ...        ...   ...     ...        ...
# 70406  2019  CHANNEL 1         PEONY-LIP  PEONY-LIP   Aug     0.0        ABC
# 70407  2019  CHANNEL 1         PEONY-LIP  PEONY-LIP   Sep     0.0        ABC
# 70408  2019  CHANNEL 1         PEONY-LIP  PEONY-LIP   Oct     0.0        ABC
# 70409  2019  CHANNEL 1         PEONY-LIP  PEONY-LIP   Nov     0.0        ABC
# 70410  2019  CHANNEL 1         PEONY-LIP  PEONY-LIP   Dec     0.0        ABC
#
# [70411 rows x 7 columns]

# %%
df_allchsalesvol.info(verbose=True)
# No NULL/NaN Values are present in the All Channel Sales Volume Table.
# there are *** Empty rows in the 'Merged Sku' column, as we can see but they have not been assigned NaN/NuLl.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70411 entries, 0 to 70410
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        70411 non-null  int64
#  1   Channel     70411 non-null  object
#  2   Sku         70411 non-null  object
#  3   Merged Sku  70411 non-null  object
#  4   Month       70411 non-null  object
#  5   Volume      70411 non-null  float64
#  6   Brand_Flag  70411 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 3.8+ MB

# %%
df_allchsalesvol.columns
# Out:
# Index(['Year', 'Channel', 'Sku', 'Merged Sku', 'Month', 'Volume',
#        'Brand_Flag'],
#       dtype='object')

# %%
print('Detailed information for all the columns: \n')
for cols in df_allchsalesunits.columns:
    print(f'{cols}:')
    print(f'{df_allchsalesunits[cols].value_counts()}\n')
# Out:
# Detailed information for all the columns:
#
# Year:
# 2018    27024
# 2019    24360
# 2017    19038
# Name: Year, dtype: int64
#
# Channel:
# CHANNEL 1    16152
# CHANNEL 3    14544
# CHANNEL 6    11808
# CHANNEL 4    11724
# CHANNEL 7     9504
# CHANNEL 2     4374
# CHANNEL 5     1392
# CHANNEL 8      924
# Name: Channel, dtype: int64
#
# Sku:
# SILK-CREAM-V2                         252
# HYDRATION-SERUM                       252
# PC-OIL                                252
# SERUM-EYE                             252
# GOLDSPUN-LIP-BALM                     252
#                                      ...
# CHANNEL 3-BEAUTY-OIL-DUO-A353490       12
# CHANNEL 3-INDG-POLISH-A344555(851)     12
# CHANNEL 3-PEARL-MED-A342905-849        12
# CHANNEL 3-HD18-A352980                 12
# PEONY-LIP                              12
# Name: Sku, Length: 657, dtype: int64
#
# Merged Sku:
#                                        19938
# SILK-CREAM-V2                            450
# ...

# %%
# Checking for duplicates in the table:
print(f'Total no. of Duplicates in the Table: \
{len(df_allchsalesvol)-len(df_allchsalesvol.drop_duplicates())}')
# Out:
# Total no. of Duplicates in the Table: 0

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.3. `Classification` table</span>

# %%
df_classification
# Out:
#        Sku #                                      Sku       Classification  \
# 0      Sku 1                              WATER-CREAM                 Core
# 1      Sku 2                              SILK-CANVAS                 Core
# 2      Sku 3                                 DS-CREAM                 Core
# 3      Sku 4                           VIOLET-C-SERUM                 Core
# 4      Sku 5                       SILK-CANVAS-TRAVEL               Travel
# ..       ...                                      ...                  ...
# 425  Sku 426  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A354258  Limited Edition Set
# 426  Sku 427  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A371858  Limited Edition Set
# 427  Sku 428                CHANNEL 3-RED-LIP-A291363                 Core
# 428  Sku 429                      SEPH-SKIN-MIST-HD17               Travel
# 429  Sku 430                          SEPH-KYOTO-HD17  Limited Edition Set
#
#         Subclass   Collection
# 0    Moisturizer        Pores
# ...

# %%
df_classification.info(verbose=True)
# No NULL/NaN Values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sku #           430 non-null    object
#  1   Sku             430 non-null    object
#  2   Classification  430 non-null    object
#  3   Subclass        430 non-null    object
#  4   Collection      430 non-null    object
# dtypes: object(5)
# memory usage: 16.9+ KB

# %%
df_classification.columns
# Out:
# Index(['Sku #', 'Sku', 'Classification', 'Subclass', 'Collection'], dtype='object')

# %%
print('Detailed information for all the columns: \n')
columns = ['Classification', 'Subclass', 'Collection']
for cols in columns:
    print(f'{cols}:')
    print(f'{df_classification[cols].value_counts()}\n')
# Out:
# Detailed information for all the columns:
#
# Classification:
# Limited Edition Set          144
# Core                          87
# Core Set                      63
# CHANNEL 3                     42
# Travel                        39
# Curated Gift                  25
# Limited Edition Full Size     20
# Curated Beauty                 5
# 0                              5
# Name: Classification, dtype: int64
#
# Subclass:
# Set               154
# Bundle             65
# Lip                48
# Curated Gift       25
# Powder             23
# Moisturizer        21
# Serum              16
# Bridge             13
# Body               12
# Cleanser            9
# Mask                9
# Mist                8
# Blot                6
# Curated Beauty      5
# 0                   5
# Eye                 4
# Oil                 2
# TSV                 2
# SPF                 2
# FS + TS GWP         1
# Name: Subclass, dtype: int64
#
# Collection:
# Holiday            60
# ...

# %%
# These rows have features set to 0;
# Let's also check if they are duplicate values or not
df_classification[df_classification['Subclass'] == 0]
# Out:
#        Sku #                Sku Classification Subclass Collection
# 235  Sku 236       CHERRY-BLUSH              0        0          0
# 256  Sku 257  HD15-KOTUR-CLUTCH              0        0          0
# 262  Sku 263          INDG-MIST              0        0          0
# 269  Sku 270   NORM-VANITY-HD16              0        0          0
# 272  Sku 273   OILY-VANITY-HD16              0        0          0

# %%
# Checking for duplicates in the table:
print(f'Total no. of Duplicates in the Table: \
{len(df_classification)-len(df_classification.drop_duplicates())}')
# Out:
# Total no. of Duplicates in the Table: 0

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.4. `COGS` table: </span>

# %%
df_cogs
# Out:
#        Sku #                                      Sku           Merged Sku  \
# 0      Sku 1                              WATER-CREAM          WATER-CREAM
# 1      Sku 2                              SILK-CANVAS          SILK-CANVAS
# 2      Sku 3                                 DS-CREAM             DS-CREAM
# 3      Sku 4                           VIOLET-C-SERUM       VIOLET-C-SERUM
# 4      Sku 5                       SILK-CANVAS-TRAVEL   SILK-CANVAS-TRAVEL
# ..       ...                                      ...                  ...
# 425  Sku 426  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A354258       BERRY-LIP-TRIO
# 426  Sku 427  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A371858       BERRY-LIP-TRIO
# 427  Sku 428                CHANNEL 3-RED-LIP-A291363              RED-LIP
# 428  Sku 429                      SEPH-SKIN-MIST-HD17  SEPH-SKIN-MIST-HD17
# 429  Sku 430                          SEPH-KYOTO-HD17      SEPH-KYOTO-HD17
#
#           COGS  MSRP
# 0     7.570000  68.0
# 1     7.720000  52.0
# ...

# %%
df_cogs.info(verbose=True)
# There is one NULL/NaN Value in the MSRP column.
# There are data quality issues in the MSRP column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sku #       430 non-null    object
#  1   Sku         430 non-null    object
#  2   Merged Sku  430 non-null    object
#  3   COGS        430 non-null    float64
#  4   MSRP        429 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 16.9+ KB

# %%
df_cogs['MSRP'].value_counts()
# Out:
# 0.0      47
# 15.0     19
# 65.0     18
# 85.0     15
# 68.0     14
#          ..
# 295.0     1
# 590.0     1
# 78.0      1
# 690.0     1
# 505.0     1
# Name: MSRP, Length: 106, dtype: int64

# %%
null_filt_cogs = (df_cogs.isna()['MSRP'] == True)
df_cogs[null_filt_cogs]
# Out:
#      Sku #                Sku         Merged Sku   COGS  MSRP
# 30  Sku 31  CHANNEL 3-A367604  CHANNEL 3-A367604  26.45   NaN

# %%
# Checking for duplicates in the table:
print(f'Total no. of Duplicates in the Table: \
{len(df_cogs)-len(df_cogs.drop_duplicates())}')
# Out:
# Total no. of Duplicates in the Table: 0

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.5. `Line` table</span>

# %%
df_line
# Out:
#        Sku #                                      Sku Line Edit
# 0      Sku 1                              WATER-CREAM  On Going
# 1      Sku 2                              SILK-CANVAS         0
# 2      Sku 3                                 DS-CREAM  On Going
# 3      Sku 4                           VIOLET-C-SERUM  On Going
# 4      Sku 5                       SILK-CANVAS-TRAVEL  On Going
# ..       ...                                      ...       ...
# 425  Sku 426  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A354258    1 Shot
# 426  Sku 427  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A371858    1 Shot
# 427  Sku 428                CHANNEL 3-RED-LIP-A291363    1 Shot
# 428  Sku 429                      SEPH-SKIN-MIST-HD17       NaN
# 429  Sku 430                          SEPH-KYOTO-HD17       NaN
#
# [430 rows x 3 columns]

# %%
df_line.info(verbose=True)
# there are NULL/NaN values in the `Line Edit` column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sku #      430 non-null    object
#  1   Sku        430 non-null    object
#  2   Line Edit  274 non-null    object
# dtypes: object(3)
# memory usage: 10.2+ KB

# %%
print('Detailed information for all the columns: \n')
for cols in df_line.columns:
    print(f'{cols}:')
    print(f'{df_line[cols].value_counts()}\n')
# Out:
# Detailed information for all the columns:
#
# Sku #:
# Sku 1      1
# Sku 296    1
# Sku 294    1
# Sku 293    1
# Sku 292    1
#           ..
# Sku 141    1
# Sku 140    1
# Sku 139    1
# Sku 138    1
# Sku 430    1
# Name: Sku #, Length: 430, dtype: int64
#
# Sku:
# WATER-CREAM                 1
# LE17-SKINCARE-TRAVEL-SET    1
# CHERRY-LIP-TRIO-OLD         1
# CHERRY-LIP-TRIO-V2          1
# CRTD-FAN-SUIMEI-2017        1
#                            ..
# PINK-SOAP-V2                1
# BLOT-4                      1
# AWAKEN-MED-TRIO             1
# SEPH-BENTO-AUG-18           1
# SEPH-KYOTO-HD17             1
# Name: Sku, Length: 430, dtype: int64
#
# Line Edit:
# 1 Shot      146
# On Going    124
# 0             4
# Name: Line Edit, dtype: int64

# %%
# Replacing NaN/NuLL values with 0
# Assuming 0 to be for products that don't have product lineup.
df_line.fillna(0, inplace=True)

# %%
df_line['Line Edit'].value_counts()
# Out:
# 0           160
# 1 Shot      146
# On Going    124
# Name: Line Edit, dtype: int64

# %%
# Checking for duplicates in the table:
print(f'Total no. of Duplicates in the Table: \
{len(df_line)-len(df_line.drop_duplicates())}')
# Out:
# Total no. of Duplicates in the Table: 0

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.6. `OOS Sku` table</span>

# %%
# This table gives information about the out-of-stoc products and Low on Stock Products
df_oos_sku
# Out:
#                          Skus Out of Stock Low WOS
# 0           SPF35 Travel Size          YES     NaN
# 1         Skin Mist Full Size          YES     NaN
# 2                   Eye Cream          YES     NaN
# 3                   Serum-Eye          YES     NaN
# 4  Ritual Starter Sets (.com)          NaN     Yes

# %%
# Feature engineering: Converting YES/Yes --> 1; NaN/No/NULL --> 0
# Setting the NaN/No/NULL --> 0
df_oos_sku.fillna(0, inplace=True)
# Setting 'YES' --> 1
df_oos_sku.replace(to_replace=['YES', 'Yes'], value=1, inplace=True)
df_oos_sku
# Out:
#                          Skus  Out of Stock  Low WOS
# 0           SPF35 Travel Size             1        0
# 1         Skin Mist Full Size             1        0
# 2                   Eye Cream             1        0
# 3                   Serum-Eye             1        0
# 4  Ritual Starter Sets (.com)             0        1

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.7. `Region` table</span>

# %%
df_region
# Out:
#      Region Name  Region Code
# 0  International            5
# 1         Canada            0
# 2        Western            1
# 3       Southern            2
# 4      Northeast            3
# 5        Central            4

# %%
df_region.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Region Name  6 non-null      object
#  1   Region Code  6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
df_region.sort_values(by='Region Code')
# Region-0: Canada
# Region-(1-4): USA
# Region-5: International (Out of US & Canada)
# Out:
#      Region Name  Region Code
# 1         Canada            0
# 2        Western            1
# 3       Southern            2
# 4      Northeast            3
# 5        Central            4
# 0  International            5

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.8. `Sku Region` table</span>

# %%
df_sku_region
# Out:
#         Channel                        Sku    Region Name
# 0     CHANNEL 1           7-DAY-BETA-CARDS         Canada
# 1     CHANNEL 1  AGELESS-PLUMP-PROTECT-SET  International
# 2     CHANNEL 1              BEAUTY-OIL-30         Canada
# 3     CHANNEL 1      BEAUTY-OIL-DELUXE-LOY        Western
# 4     CHANNEL 1          BEAUTY-OIL-TRAVEL       Southern
# ...         ...                        ...            ...
# 2346  CHANNEL 8             SEPH-MIST-HD18  International
# 2347  CHANNEL 8        SEPH-BEST-SELL-HD18         Canada
# 2348  CHANNEL 8                      SPF35        Western
# 2349  CHANNEL 8        SKIN-MIST-TRAVEL-V2       Southern
# 2350  CHANNEL 8                   DS-CREAM      Northeast
#
# [2351 rows x 3 columns]

# %%
df_sku_region.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2351 entries, 0 to 2350
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Channel      2351 non-null   object
#  1   Sku          2351 non-null   object
#  2   Region Name  2351 non-null   object
# dtypes: object(3)
# memory usage: 55.2+ KB

# %%
print('Detailed information for all the columns: \n')
for cols in df_sku_region.columns:
    print(f'{cols}:')
    print(f'{df_sku_region[cols].value_counts()}\n')
# Out:
# Detailed information for all the columns:
#
# Channel:
# CHANNEL 1    497
# CHANNEL 3    433
# CHANNEL 6    340
# CHANNEL 4    338
# CHANNEL 7    322
# CHANNEL 2    320
# CHANNEL 8     52
# CHANNEL 5     49
# Name: Channel, dtype: int64
#
# Sku:
# LIP-BALM-RED-HD16        8
# ESSENCE                  8
# WATER-CREAM              8
# VIOLET-C-MASK            8
# CL-POWDER                8
#                         ..
# YUGURE-FAN-2018          1
# CL-POWDER-TRAVEL-V2      1
# DP-POWDER-TRAVEL-V3      1
# INDG-POWDER-TRAVEL-V2    1
# DS-MASK-V1               1
# Name: Sku, Length: 657, dtype: int64
#
# Region Name:
# Canada           337
# International    336
# Western          336
# Southern         336
# Northeast        336
# Central          335
# Region Name      335
# Name: Region Name, dtype: int64

# %%
len(df_sku_region)-len(df_sku_region.drop_duplicates())
# Out:
# 0

# %%
# 335 Rows in the df_sku_region have 'Region Name' = Region Name
# Not a valid datapoint
# We can assume those to have Unassigned Region Name
df_sku_region[(df_sku_region['Region Name'] == 'Region Name')]
# Out:
#         Channel                 Sku  Region Name
# 7     CHANNEL 1                BLOT  Region Name
# 14    CHANNEL 1  BRACELET-CRTD-LE16  Region Name
# 21    CHANNEL 1     BR-SERUM-TRAVEL  Region Name
# 28    CHANNEL 1    CHERRY-LIP LINER  Region Name
# 35    CHANNEL 1        CL-POWDER-PK  Region Name
# ...         ...                 ...          ...
# 2317  CHANNEL 8           GT-POWDER  Region Name
# 2324  CHANNEL 8   LIP-BALM-RED-HD16  Region Name
# 2331  CHANNEL 8       MED-PEARL-EYE  Region Name
# 2338  CHANNEL 8  WATER-CREAM-TRAVEL  Region Name
# 2345  CHANNEL 8     SEPH-BENTO-HD18  Region Name
#
# [335 rows x 3 columns]

# %%
df_sku_region.replace(to_replace='Region Name', value= 'Unassigned', inplace=True)

# %%
df_sku_region['Region Name'].value_counts()
# Out:
# Canada           337
# International    336
# Western          336
# Southern         336
# Northeast        336
# Central          335
# Unassigned       335
# Name: Region Name, dtype: int64

# %%
# Merge the df_sku_region & df_region

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.9. `Sku` table</span>

# %%
df_sku
# Out:
#        Sku #                                      Sku           Merged Sku  \
# 0      Sku 1                              WATER-CREAM          WATER-CREAM
# 1      Sku 2                              SILK-CANVAS          SILK-CANVAS
# 2      Sku 3                                 DS-CREAM             DS-CREAM
# 3      Sku 4                           VIOLET-C-SERUM       VIOLET-C-SERUM
# 4      Sku 5                       SILK-CANVAS-TRAVEL   SILK-CANVAS-TRAVEL
# ..       ...                                      ...                  ...
# 425  Sku 426  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A354258       BERRY-LIP-TRIO
# 426  Sku 427  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A371858       BERRY-LIP-TRIO
# 427  Sku 428                CHANNEL 3-RED-LIP-A291363              RED-LIP
# 428  Sku 429                      SEPH-SKIN-MIST-HD17  SEPH-SKIN-MIST-HD17
# 429  Sku 430                          SEPH-KYOTO-HD17      SEPH-KYOTO-HD17
#
#      Launch Date
# 0         201700
# 1           2018
# ...

# %%
# No NULL/NaN Values in the table.
## There are data quality issues in the `Launch Date` Column
df_sku.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sku #        430 non-null    object
#  1   Sku          430 non-null    object
#  2   Merged Sku   430 non-null    object
#  3   Launch Date  430 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 13.6+ KB

# %%
# this column can be ignored as it's not used as mentioned in the Table description 
# of the problem statment
df_sku['Launch Date'].value_counts()
# Out:
# 2018      232
# 2016      143
# 2019       33
# 201601      5
# 201700      3
# 201605      3
# 201704      3
# 201702      3
# 201705      3
# 201701      1
# 201706      1
# Name: Launch Date, dtype: int64

# %%
# Correcting the inconsistency in the data:
df_sku['Launch Date'] = df_sku['Launch Date'].apply(lambda x: str(x)[:4])

# %%
df_sku['Launch Date'].value_counts()
# Out:
# 2018    232
# 2016    151
# 2019     33
# 2017     14
# Name: Launch Date, dtype: int64

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> 3.10. `Company` table</span>

# %%
# There is no Channel ABC, So we need to drop that row:
df_company.drop([0], inplace=True)

# %%
df_company
# Out:
#   CHANNEL CHANNEL Name COMPANY
# 1       1    CHANNEL 1     ABC
# 2       2    CHANNEL 2     ABC
# 3       3    CHANNEL 3     ABC
# 4       4    CHANNEL 4     ABC
# 5       5    CHANNEL 5     ABC
# 6       6    CHANNEL 6     ABC
# 7       7    CHANNEL 7     ABC
# 8       8    CHANNEL 8     ABC

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 24px; font-weight: Bold"> Merging all the necessary dataframes: </span>
#
# https://stackoverflow.com/questions/53645882/pandas-merging-101

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> Merging `All Channel Sales Units` and `Company`tables: </span>

# %%
df_combine_salesunit = df_allchsalesunits.merge(df_company, left_on='Channel', right_on='CHANNEL Name')

# %%
df_combine_salesunit.sample(5)
# Drop 'Channel', 'CHANNEL Name' columns
# Out:
#        Year    Channel                    Sku  Merged Sku Month  Units  \
# 28522  2018  CHANNEL 2             CHERRY-LIP  CHERRY-LIP   May   11.0
# 15783  2019  CHANNEL 5                DS-MASK     DS-MASK   Apr  579.0
# 24064  2019  CHANNEL 4  CL-POWDER-TRAVEL-COMP               May    0.0
# 58747  2018  CHANNEL 1         GIFT-BOX-LARGE               Feb    0.0
# 45959  2018  CHANNEL 6   ESSENCE-SAMPLER-COMP               Jun    0.0
#
#       Brand_Flag CHANNEL CHANNEL Name COMPANY
# 28522        ABC       2    CHANNEL 2     ABC
# 15783        ABC       5    CHANNEL 5     ABC
# 24064        ABC       4    CHANNEL 4     ABC
# 58747        ABC       1    CHANNEL 1     ABC
# 45959        ABC       6    CHANNEL 6     ABC

# %%
df_combine_salesunit.drop(columns=[ 'Channel', 'CHANNEL Name'], inplace=True)

# %%
df_combine_salesunit.sample(5)
# Out:
#        Year                        Sku         Merged Sku Month  Units  \
# 3347   2017  TSN-EYE-CREAM-TRAVEL-COMP                      Dec    0.0
# 52710  2019  TSN-SKIN-MIST-TRAVEL-GIFT                      Jan    0.0
# 58305  2018            CRTD-HIKARI-FAN    CRTD-HIKARI-FAN   Apr    0.0
# 39500  2019          KOTUR-CLUTCH-CRTD  KOTUR-CLUTCH-CRTD   Mar    0.0
# 63182  2018            KIRI-DRY-RITUAL    KIRI-DRY-RITUAL   Sep    3.0
#
#       Brand_Flag CHANNEL COMPANY
# 3347         ABC       3     ABC
# 52710        ABC       6     ABC
# 58305        ABC       1     ABC
# 39500        ABC       7     ABC
# 63182        ABC       1     ABC

# %%
# We can safely drop the'COMPANY', 'Brand_Flag' columns as all the products belongs to ABC Company.
df_combine_salesunit.drop(columns=[ 'COMPANY', 'Brand_Flag'], inplace=True)

# %%
df_combine_salesunit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70422 entries, 0 to 70421
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        70422 non-null  int64
#  1   Sku         70422 non-null  object
#  2   Merged Sku  70398 non-null  object
#  3   Month       70422 non-null  object
#  4   Units       70422 non-null  float64
#  5   CHANNEL     70422 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> Merge `df_classification`, `df_sku`, `df_cogs` on `SKU #` column </span>

# %%
# merging df_sku and df_classification:
df_sku_cogs_class = df_classification.merge(df_sku, left_on='Sku #', right_on='Sku #')
df_sku_cogs_class.head(10)
# Out:
#     Sku #               Sku_x       Classification     Subclass  \
# 0   Sku 1         WATER-CREAM                 Core  Moisturizer
# 1   Sku 2         SILK-CANVAS                 Core       Bridge
# 2   Sku 3            DS-CREAM                 Core  Moisturizer
# 3   Sku 4      VIOLET-C-SERUM                 Core        Serum
# 4   Sku 5  SILK-CANVAS-TRAVEL               Travel       Bridge
# 5   Sku 6             ESSENCE                 Core        Serum
# 6   Sku 7          DP-CLEANSE                 Core     Cleanser
# 7   Sku 8      SEPH-BOTF-2018  Limited Edition Set          Set
# 8   Sku 9              PC-OIL                 Core     Cleanser
# 9  Sku 10           SKIN-MIST                 Core         Mist
#
#        Collection               Sku_y          Merged Sku Launch Date
# 0           Pores         WATER-CREAM         WATER-CREAM        2017
# 1          Bridge         SILK-CANVAS         SILK-CANVAS        2018
# ...

# %%
df_sku_cogs_class.shape
# Out:
# (430, 8)

# %%
# Dropping the `Sku_y` column
df_sku_cogs_class.drop(columns='Sku_y', inplace=True)

# %%
# Rename the `Sku_x` column to `Sku`:
df_sku_cogs_class.rename(columns = {'Sku_x':'Sku'}, inplace = True)
df_sku_cogs_class.head(10)
# Out:
#     Sku #                 Sku       Classification     Subclass  \
# 0   Sku 1         WATER-CREAM                 Core  Moisturizer
# 1   Sku 2         SILK-CANVAS                 Core       Bridge
# 2   Sku 3            DS-CREAM                 Core  Moisturizer
# 3   Sku 4      VIOLET-C-SERUM                 Core        Serum
# 4   Sku 5  SILK-CANVAS-TRAVEL               Travel       Bridge
# 5   Sku 6             ESSENCE                 Core        Serum
# 6   Sku 7          DP-CLEANSE                 Core     Cleanser
# 7   Sku 8      SEPH-BOTF-2018  Limited Edition Set          Set
# 8   Sku 9              PC-OIL                 Core     Cleanser
# 9  Sku 10           SKIN-MIST                 Core         Mist
#
#        Collection          Merged Sku Launch Date
# 0           Pores         WATER-CREAM        2017
# 1          Bridge         SILK-CANVAS        2018
# 2       Dewy Skin            DS-CREAM        2019
# 3     Brightening      VIOLET-C-SERUM        2019
# ...

# %%
df_sku_cogs_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 430 entries, 0 to 429
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sku #           430 non-null    object
#  1   Sku             430 non-null    object
#  2   Classification  430 non-null    object
#  3   Subclass        430 non-null    object
#  4   Collection      430 non-null    object
#  5   Merged Sku      430 non-null    object
#  6   Launch Date     430 non-null    object
# dtypes: object(7)
# memory usage: 26.9+ KB

# %%
df_sku_cogs_class = df_sku_cogs_class.merge(df_cogs, left_on='Sku #', right_on='Sku #')
df_sku_cogs_class.head(10)
# Out:
#     Sku #               Sku_x       Classification     Subclass  \
# 0   Sku 1         WATER-CREAM                 Core  Moisturizer
# 1   Sku 2         SILK-CANVAS                 Core       Bridge
# 2   Sku 3            DS-CREAM                 Core  Moisturizer
# 3   Sku 4      VIOLET-C-SERUM                 Core        Serum
# 4   Sku 5  SILK-CANVAS-TRAVEL               Travel       Bridge
# 5   Sku 6             ESSENCE                 Core        Serum
# 6   Sku 7          DP-CLEANSE                 Core     Cleanser
# 7   Sku 8      SEPH-BOTF-2018  Limited Edition Set          Set
# 8   Sku 9              PC-OIL                 Core     Cleanser
# 9  Sku 10           SKIN-MIST                 Core         Mist
#
#        Collection        Merged Sku_x Launch Date               Sku_y  \
# 0           Pores         WATER-CREAM        2017         WATER-CREAM
# 1          Bridge         SILK-CANVAS        2018         SILK-CANVAS
# ...

# %%
# Dropping the `Sku_y` and `Merged Sku_y` columns
df_sku_cogs_class.drop(columns= ['Sku_y', 'Merged Sku_y'], inplace=True)

# %%
# Rename the `Sku_x` column to `Sku`:
df_sku_cogs_class.rename(columns = {'Sku_x':'Sku', 'Merged Sku_x': 'Merged Sku'}, inplace = True)
df_sku_cogs_class.head(10)
# Out:
#     Sku #                 Sku       Classification     Subclass  \
# 0   Sku 1         WATER-CREAM                 Core  Moisturizer
# 1   Sku 2         SILK-CANVAS                 Core       Bridge
# 2   Sku 3            DS-CREAM                 Core  Moisturizer
# 3   Sku 4      VIOLET-C-SERUM                 Core        Serum
# 4   Sku 5  SILK-CANVAS-TRAVEL               Travel       Bridge
# 5   Sku 6             ESSENCE                 Core        Serum
# 6   Sku 7          DP-CLEANSE                 Core     Cleanser
# 7   Sku 8      SEPH-BOTF-2018  Limited Edition Set          Set
# 8   Sku 9              PC-OIL                 Core     Cleanser
# 9  Sku 10           SKIN-MIST                 Core         Mist
#
#        Collection          Merged Sku Launch Date     COGS  MSRP
# 0           Pores         WATER-CREAM        2017  7.57000  68.0
# 1          Bridge         SILK-CANVAS        2018  7.72000  52.0
# 2       Dewy Skin            DS-CREAM        2019  7.02000  68.0
# ...

# %%
df_sku_cogs_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 430 entries, 0 to 429
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sku #           430 non-null    object
#  1   Sku             430 non-null    object
#  2   Classification  430 non-null    object
#  3   Subclass        430 non-null    object
#  4   Collection      430 non-null    object
#  5   Merged Sku      430 non-null    object
#  6   Launch Date     430 non-null    object
#  7   COGS            430 non-null    float64
#  8   MSRP            429 non-null    float64
# dtypes: float64(2), object(7)
# memory usage: 33.6+ KB

# %%
# Setting the NaN/Null MRP as 0:
df_sku_cogs_class.fillna(0, inplace=True)

# %%
df_sku_cogs_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 430 entries, 0 to 429
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sku #           430 non-null    object
#  1   Sku             430 non-null    object
#  2   Classification  430 non-null    object
#  3   Subclass        430 non-null    object
#  4   Collection      430 non-null    object
#  5   Merged Sku      430 non-null    object
#  6   Launch Date     430 non-null    object
#  7   COGS            430 non-null    float64
#  8   MSRP            430 non-null    float64
# dtypes: float64(2), object(7)
# memory usage: 33.6+ KB

# %%
# MSRP has been set to 0 for the given items:
df_sku_cogs_class[(df_sku_cogs_class['MSRP'] == 0)]
# Out:
#        Sku #                                            Sku  \
# 30    Sku 31                              CHANNEL 3-A367604
# 54    Sku 55                 CHANNEL 3-MEMORY-SERUM-A278328
# 55    Sku 56              CHANNEL 3-AGELESS-EYE-OTO-A283138
# 68    Sku 69                        CHANNEL 3-OILx1-A267271
# 77    Sku 78                    CHANNEL 3-LUMINOUS-FACE-EYE
# 112  Sku 113               CHANNEL 3-BRIGHTENING-TOUMEI-DUO
# 131  Sku 132                      CHANNEL 3-HYDRATE-PROTECT
# 179  Sku 180                           VIOLET-C-MASK-TRAVEL
# 283  Sku 284                               LIP-LINER-CHERRY
# 284  Sku 285                         BLUE-STARTER-SENSITIVE
# 285  Sku 286                       PURPLE-STARTER-HYDRATING
# 286  Sku 287                        WATER-PLUMP-PROTECT-SET
# 287  Sku 288                            SENSITIVE-RITUAL-V2
# 292  Sku 293                             CHERRY-LIP-TRIO-V2
# 293  Sku 294                            CHERRY-LIP-TRIO-OLD
# ...

# %%
df_sku_cogs_class[(df_sku_cogs_class['COGS'] == 0)]
# Out:
#        Sku #                                            Sku  \
# 294  Sku 295                      CL-POWDER-TRAVEL-REFERRAL
# 296  Sku 297                                VIOLET-C-TRAVEL
# 299  Sku 300           CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 352  Sku 353                              CLEANSE-TRIO-COMP
# 353  Sku 354                                 PC-OIL-SAMPLER
# 410  Sku 411  CHANNEL 3-WSL (while supplies last) - A290105
#
#           Classification  Subclass     Collection  \
# 294               Travel    Powder  Kyoto Cleanse
# 296               Travel      Mask    Brightening
# 299            CHANNEL 3       Set      Other Set
# 352  Limited Edition Set    Bundle      Other Set
# 353                 Core  Cleanser  Kyoto Cleanse
# 410            CHANNEL 3    Bundle   Other Bundle
#
#                                         Merged Sku Launch Date  COGS  MSRP
# 294                      CL-POWDER-TRAVEL-REFERRAL        2018   0.0   0.0
# ...

# %%
zero_cogs_sku_list = []
for item in df_sku_cogs_class['Sku #'][(df_sku_cogs_class['COGS'] == 0)]:
    zero_cogs_sku_list.append(item)

# %%
# Products `Sku #` with Zero COGS:   
print(f'Products with Zero COGS : {zero_cogs_sku_list}')
# Out:
# Products with Zero COGS : ['Sku 295', 'Sku 297', 'Sku 300', 'Sku 353', 'Sku 354', 'Sku 411']

# %%
zero_cogs_sku_namelist = []
for item in df_sku_cogs_class['Sku'][(df_sku_cogs_class['COGS'] == 0)]:
    zero_cogs_sku_namelist.append(item)

# %%
# Products with Zero COGS:   
print(f'Products with Zero COGS : {zero_cogs_sku_namelist}')
# Out:
# Products with Zero COGS : ['CL-POWDER-TRAVEL-REFERRAL', 'VIOLET-C-TRAVEL', 'CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY', 'CLEANSE-TRIO-COMP', 'PC-OIL-SAMPLER', 'CHANNEL 3-WSL (while supplies last) - A290105']

# %%
df_allchsalesunits[(df_allchsalesunits['Sku'] == 'CL-POWDER-TRAVEL-REFERRAL')]
# Out:
#        Year    Channel                        Sku                 Merged Sku  \
# 57258  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57259  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57260  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57261  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57262  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57263  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57264  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57265  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57266  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57267  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# 57268  2017  CHANNEL 1  CL-POWDER-TRAVEL-REFERRAL  CL-POWDER-TRAVEL-REFERRAL
# ...

# %%
df_allchsalesunits[(df_allchsalesunits['Sku'] == 'VIOLET-C-TRAVEL')]
# Out:
#        Year    Channel              Sku       Merged Sku Month  Units  \
# 57282  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Jan    0.0
# 57283  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Feb    0.0
# 57284  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Mar    0.0
# 57285  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Apr    0.0
# 57286  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   May    0.0
# 57287  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Jun    9.0
# 57288  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Jul    9.0
# 57289  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Aug    0.0
# 57290  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Sep    0.0
# 57291  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Oct    0.0
# 57292  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Nov    0.0
# 57293  2017  CHANNEL 1  VIOLET-C-TRAVEL  VIOLET-C-TRAVEL   Dec    0.0
# ...

# %%
df_allchsalesunits[(df_allchsalesunits['Sku'] == 'CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY')]
# Out:
#        Year    Channel                                   Sku  \
# 4428   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4429   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4430   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4431   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4432   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4433   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4434   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4435   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4436   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4437   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4438   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 4439   2017  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 8940   2018  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# 8941   2018  CHANNEL 3  CHANNEL 3-LUMINOUS-TREASURES-HOLIDAY
# ...

# %%
df_allchsalesunits[(df_allchsalesunits['Sku'] == 'CLEANSE-TRIO-COMP')]
# Out:
#        Year    Channel                Sku         Merged Sku Month  Units  \
# 62394  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Jan    0.0
# 62395  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Feb  607.0
# 62396  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Mar  243.0
# 62397  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Apr    0.0
# 62398  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   May    0.0
# 62399  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Jun    0.0
# 62400  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Jul    0.0
# 62401  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Aug    0.0
# 62402  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Sep    0.0
# 62403  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Oct    0.0
# 62404  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Nov    0.0
# 62405  2018  CHANNEL 1  CLEANSE-TRIO-COMP  CLEANSE-TRIO-COMP   Dec    0.0
# ...

# %%
df_allchsalesunits[(df_allchsalesunits['Sku'] == 'PC-OIL-SAMPLER')]
# Out:
#        Year    Channel             Sku      Merged Sku Month   Units  \
# 62430  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Jan     0.0
# 62431  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Feb     0.0
# 62432  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Mar  1659.0
# 62433  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Apr  1744.0
# 62434  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   May  2089.0
# 62435  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Jun  2115.0
# 62436  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Jul  1789.0
# 62437  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Aug  2080.0
# 62438  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Sep  2945.0
# 62439  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Oct  2099.0
# 62440  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Nov  1729.0
# 62441  2018  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Dec  2213.0
# 68142  2019  CHANNEL 1  PC-OIL-SAMPLER  PC-OIL-SAMPLER   Jan  1860.0
# ...

# %%
df_allchsalesunits[(df_allchsalesunits['Sku'] == 'CHANNEL 3-WSL (while supplies last) - A290105')]
# Out:
# Empty DataFrame
# Columns: [Year, Channel, Sku, Merged Sku, Month, Units, Brand_Flag]
# Index: []

# %%
df_sku_cogs_class[(df_sku_cogs_class['Classification'] == 'CHANNEL 3')]
# Out:
#        Sku #                                                Sku  \
# 13    Sku 14                    CHANNEL 3-TSV-JUNE-2018-A305748
# 30    Sku 31                                  CHANNEL 3-A367604
# 42    Sku 43   CHANNEL 3-OVERNIGHT RITUAL SKINCARE TRIO-A353492
# 49    Sku 50                   CHANNEL 3-BEAUTY-OIL-DUO-A353490
# 55    Sku 56                  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 63    Sku 64                     CHANNEL 3-JAN-2018-OTO-A307725
# 73    Sku 74                                  CHANNEL 3-A352973
# 77    Sku 78                        CHANNEL 3-LUMINOUS-FACE-EYE
# 86    Sku 87                           CHANNEL 3-OTO-18-A305134
# 91    Sku 92                     CHANNEL 3-JAN-2018-EVT-A297954
# 95    Sku 96                CHANNEL 3-HOLIDAY-HYDRATION-A352977
# 106  Sku 107                     CHANNEL 3-LIP-BALM-SET-A297981
# 112  Sku 113                   CHANNEL 3-BRIGHTENING-TOUMEI-DUO
# 113  Sku 114                          CHANNEL 3-HD18-A352980-v3
# ...

# %%
df_allchsalesunits[(df_allchsalesunits['Sku'] == 'CHANNEL 3-HD18-A344592')]
# Out:
#        Year    Channel                     Sku              Merged Sku Month  \
# 9312   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Jan
# 9313   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Feb
# 9314   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Mar
# 9315   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Apr
# 9316   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   May
# 9317   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Jun
# 9318   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Jul
# 9319   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Aug
# 9320   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Sep
# 9321   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Oct
# 9322   2018  CHANNEL 3  CHANNEL 3-HD18-A344592  CHANNEL 3-HD18-A344592   Nov
# ...

# %%
# Merging the Product Line Table and the df_sku_cogs_class

# %%
df_sku_cogs_class = df_sku_cogs_class.merge(df_line, left_on='Sku #', right_on='Sku #')

# %%
df_sku_cogs_class.head()
# Out:
#    Sku #               Sku_x Classification     Subclass   Collection  \
# 0  Sku 1         WATER-CREAM           Core  Moisturizer        Pores
# 1  Sku 2         SILK-CANVAS           Core       Bridge       Bridge
# 2  Sku 3            DS-CREAM           Core  Moisturizer    Dewy Skin
# 3  Sku 4      VIOLET-C-SERUM           Core        Serum  Brightening
# 4  Sku 5  SILK-CANVAS-TRAVEL         Travel       Bridge       Bridge
#
#            Merged Sku Launch Date  COGS  MSRP               Sku_y Line Edit
# 0         WATER-CREAM        2017  7.57  68.0         WATER-CREAM  On Going
# 1         SILK-CANVAS        2018  7.72  52.0         SILK-CANVAS         0
# 2            DS-CREAM        2019  7.02  68.0            DS-CREAM  On Going
# 3      VIOLET-C-SERUM        2019  9.34  88.0      VIOLET-C-SERUM  On Going
# 4  SILK-CANVAS-TRAVEL        2019  3.50  20.0  SILK-CANVAS-TRAVEL  On Going

# %%
# Dropping the `Sku_y` column
df_sku_cogs_class.drop(columns='Sku_y', inplace=True)

# %%
# Rename the `Sku_x` column to `Sku`:
df_sku_cogs_class.rename(columns = {'Sku_x':'Sku'}, inplace = True)
df_sku_cogs_class.head(10)
# Out:
#     Sku #                 Sku       Classification     Subclass  \
# 0   Sku 1         WATER-CREAM                 Core  Moisturizer
# 1   Sku 2         SILK-CANVAS                 Core       Bridge
# 2   Sku 3            DS-CREAM                 Core  Moisturizer
# 3   Sku 4      VIOLET-C-SERUM                 Core        Serum
# 4   Sku 5  SILK-CANVAS-TRAVEL               Travel       Bridge
# 5   Sku 6             ESSENCE                 Core        Serum
# 6   Sku 7          DP-CLEANSE                 Core     Cleanser
# 7   Sku 8      SEPH-BOTF-2018  Limited Edition Set          Set
# 8   Sku 9              PC-OIL                 Core     Cleanser
# 9  Sku 10           SKIN-MIST                 Core         Mist
#
#        Collection          Merged Sku Launch Date     COGS  MSRP Line Edit
# 0           Pores         WATER-CREAM        2017  7.57000  68.0  On Going
# 1          Bridge         SILK-CANVAS        2018  7.72000  52.0         0
# ...

# %% [markdown]
# Merge `SKU Region` and `Region` tables

# %%
df_skuregion_comb = df_sku_region.merge(df_region, on='Region Name', how='left')

# %%
df_skuregion_comb.fillna(6, inplace=True)

# %%
df_skuregion_comb
# Out:
#         Channel                        Sku    Region Name  Region Code
# 0     CHANNEL 1           7-DAY-BETA-CARDS         Canada          0.0
# 1     CHANNEL 1  AGELESS-PLUMP-PROTECT-SET  International          5.0
# 2     CHANNEL 1              BEAUTY-OIL-30         Canada          0.0
# 3     CHANNEL 1      BEAUTY-OIL-DELUXE-LOY        Western          1.0
# 4     CHANNEL 1          BEAUTY-OIL-TRAVEL       Southern          2.0
# ...         ...                        ...            ...          ...
# 2346  CHANNEL 8             SEPH-MIST-HD18  International          5.0
# 2347  CHANNEL 8        SEPH-BEST-SELL-HD18         Canada          0.0
# 2348  CHANNEL 8                      SPF35        Western          1.0
# 2349  CHANNEL 8        SKIN-MIST-TRAVEL-V2       Southern          2.0
# 2350  CHANNEL 8                   DS-CREAM      Northeast          3.0
#
# [2351 rows x 4 columns]

# %%
df_skuregion_comb['Region Code'].value_counts()
# Out:
# 0.0    337
# 5.0    336
# 1.0    336
# 2.0    336
# 3.0    336
# 4.0    335
# 6.0    335
# Name: Region Code, dtype: int64

# %%
df_sku_cogs_class = df_sku_cogs_class.merge(df_skuregion_comb, left_on='Sku', right_on='Sku')

# %%
#Creating another Dataframe to store the Preliminary merged SKU details
df_final_sku_details = df_sku_cogs_class.copy(deep=True)

# %%
df_final_sku_details.head(5)
# Out:
#    Sku #          Sku Classification     Subclass Collection   Merged Sku  \
# 0  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
# 1  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
# 2  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
# 3  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
# 4  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
#
#   Launch Date  COGS  MSRP Line Edit    Channel    Region Name  Region Code
# 0        2017  7.57  68.0  On Going  CHANNEL 1        Western          1.0
# 1        2017  7.57  68.0  On Going  CHANNEL 2      Northeast          3.0
# 2        2017  7.57  68.0  On Going  CHANNEL 3  International          5.0
# 3        2017  7.57  68.0  On Going  CHANNEL 4     Unassigned          6.0
# 4        2017  7.57  68.0  On Going  CHANNEL 5        Western          1.0

# %%
df_final_sku_details.isna().sum()
# Out:
# Sku #             0
# Sku               0
# Classification    0
# Subclass          0
# Collection        0
# Merged Sku        0
# Launch Date       0
# COGS              0
# MSRP              0
# Line Edit         0
# Channel           0
# Region Name       0
# Region Code       0
# dtype: int64

# %%
df_final_sku_details[(df_final_sku_details['Classification'] == 0)]
# Out:
#         Sku #                Sku Classification Subclass Collection  \
# 880   Sku 236       CHERRY-BLUSH              0        0          0
# 881   Sku 236       CHERRY-BLUSH              0        0          0
# 882   Sku 236       CHERRY-BLUSH              0        0          0
# 883   Sku 236       CHERRY-BLUSH              0        0          0
# 884   Sku 236       CHERRY-BLUSH              0        0          0
# 885   Sku 236       CHERRY-BLUSH              0        0          0
# 1006  Sku 257  HD15-KOTUR-CLUTCH              0        0          0
# 1007  Sku 257  HD15-KOTUR-CLUTCH              0        0          0
# 1008  Sku 257  HD15-KOTUR-CLUTCH              0        0          0
# 1009  Sku 257  HD15-KOTUR-CLUTCH              0        0          0
# 1010  Sku 257  HD15-KOTUR-CLUTCH              0        0          0
# 1011  Sku 257  HD15-KOTUR-CLUTCH              0        0          0
# 1042  Sku 263          INDG-MIST              0        0          0
# ...

# %%
df_final_sku_details['Classification'].value_counts()
# Out:
# Core                         398
# Limited Edition Set          334
# Core Set                     181
# Travel                       160
# Curated Gift                  91
# Limited Edition Full Size     50
# CHANNEL 3                     49
# 0                             30
# Curated Beauty                25
# Name: Classification, dtype: int64

# %%
df_final_sku_details['Channel']
# Out:
# 0       CHANNEL 1
# 1       CHANNEL 2
# 2       CHANNEL 3
# 3       CHANNEL 4
# 4       CHANNEL 5
#           ...
# 1313    CHANNEL 3
# 1314    CHANNEL 3
# 1315    CHANNEL 6
# 1316    CHANNEL 7
# 1317    CHANNEL 6
# Name: Channel, Length: 1318, dtype: object

# %%
df_final_sku_details['Channel'] = df_final_sku_details['Channel'].apply(lambda x: str(x)[8:])

# %%
df_final_sku_details['Channel']
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 1313    3
# 1314    3
# 1315    6
# 1316    7
# 1317    6
# Name: Channel, Length: 1318, dtype: object

# %%
df_final_sku_details['Region Code'] = df_final_sku_details['Region Code'].apply(lambda x: int(x))

# %%
df_final_sku_details.drop(columns='Region Name', inplace=True)

# %%
df_final_sku_details.head()
# Out:
#    Sku #          Sku Classification     Subclass Collection   Merged Sku  \
# 0  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
# 1  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
# 2  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
# 3  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
# 4  Sku 1  WATER-CREAM           Core  Moisturizer      Pores  WATER-CREAM
#
#   Launch Date  COGS  MSRP Line Edit Channel  Region Code
# 0        2017  7.57  68.0  On Going       1            1
# 1        2017  7.57  68.0  On Going       2            3
# 2        2017  7.57  68.0  On Going       3            5
# 3        2017  7.57  68.0  On Going       4            6
# 4        2017  7.57  68.0  On Going       5            1

# %%
df_final_sku_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1318 entries, 0 to 1317
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sku #           1318 non-null   object
#  1   Sku             1318 non-null   object
#  2   Classification  1318 non-null   object
#  3   Subclass        1318 non-null   object
#  4   Collection      1318 non-null   object
#  5   Merged Sku      1318 non-null   object
#  6   Launch Date     1318 non-null   object
#  7   COGS            1318 non-null   float64
#  8   MSRP            1318 non-null   float64
#  9   Line Edit       1318 non-null   object
#  10  Channel         1318 non-null   object
#  11  Region Code     1318 non-null   int64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 133.9+ KB

# %% [markdown]
# <span style="font-family: SF Pro Display; font-size: 18px; font-weight: Bold"> Export the Sku details table: </span>

# %%
# CSV - File
df_final_sku_details.to_csv('Sku_Final-00.csv', encoding='utf-8', index=False)
# Excel-File
df_final_sku_details.to_excel('Sku_Final-00.xlsx', index=False)

# %%
df_final_sku_details[df_final_sku_details['Sku'].str.contains('CHANNEL 3')]
# Out:
#         Sku #                                      Sku  \
# 67     Sku 11            CHANNEL 3-SILK-CANVAS-A297953
# 82     Sku 14          CHANNEL 3-TSV-JUNE-2018-A305748
# 132    Sku 25               CHANNEL 3-VC-SERUM-A353473
# 133    Sku 26             CHANNEL 3-NECK-CREAM-A353488
# 143    Sku 29          CHANNEL 3-PEARL-LGT-A342905-848
# ...       ...                                      ...
# 1310  Sku 424            CHANNEL 3-SILK-CANVAS-A371861
# 1311  Sku 425       CHANNEL 3-SUPERSIZE-PC-OIL-A371563
# 1312  Sku 426  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A354258
# 1313  Sku 427  CHANNEL 3-BEAUTY-BERRY-LIP-TRIO-A371858
# 1314  Sku 428                CHANNEL 3-RED-LIP-A291363
#
#                  Classification     Subclass     Collection  \
# 67                         Core       Bridge         Bridge
# 82                    CHANNEL 3          TSV            TSV
# 132                        Core        Serum    Brightening
# ...

# %%
df_allchsalesunits[df_allchsalesunits['Sku'].str.contains('CHANNEL 3')]
# Out:
#        Year    Channel                                Sku  \
# 3636   2017  CHANNEL 3  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3637   2017  CHANNEL 3  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3638   2017  CHANNEL 3  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3639   2017  CHANNEL 3  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3640   2017  CHANNEL 3  CHANNEL 3-AGELESS-EYE-OTO-A283138
# ...     ...        ...                                ...
# 14539  2019  CHANNEL 3          CHANNEL 3-RED-LIP-A291363
# 14540  2019  CHANNEL 3          CHANNEL 3-RED-LIP-A291363
# 14541  2019  CHANNEL 3          CHANNEL 3-RED-LIP-A291363
# 14542  2019  CHANNEL 3          CHANNEL 3-RED-LIP-A291363
# 14543  2019  CHANNEL 3          CHANNEL 3-RED-LIP-A291363
#
#                               Merged Sku Month        Units Brand_Flag
# 3636   CHANNEL 3-AGELESS-EYE-OTO-A283138   Jan  1808.071000        ABC
# 3637   CHANNEL 3-AGELESS-EYE-OTO-A283138   Feb   597.000000        ABC
# ...

# %%
df_allchsalesvol['Sku'][df_allchsalesvol['Sku'].str.contains('CHANNEL 3')]
# Out:
# 3636     CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3637     CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3638     CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3639     CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3640     CHANNEL 3-AGELESS-EYE-OTO-A283138
#                        ...
# 51242            CHANNEL 3-RED-LIP-A291363
# 51243            CHANNEL 3-RED-LIP-A291363
# 51244            CHANNEL 3-RED-LIP-A291363
# 51245            CHANNEL 3-RED-LIP-A291363
# 51246            CHANNEL 3-RED-LIP-A291363
# Name: Sku, Length: 3384, dtype: object

# %%
df_combine_salesunit[df_combine_salesunit['Sku'].str.contains('AGELESS-EYE-OTO-A283138')]
# Out:
#        Year                                Sku  \
# 3636   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3637   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3638   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3639   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3640   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3641   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3642   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3643   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3644   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3645   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3646   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 3647   2017  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 8148   2018  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 8149   2018  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 8150   2018  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 8151   2018  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 8152   2018  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 8153   2018  CHANNEL 3-AGELESS-EYE-OTO-A283138
# 8154   2018  CHANNEL 3-AGELESS-EYE-OTO-A283138
# ...

# %%
df_salesunit_combined = df_combine_salesunit.merge(df_sku_cogs_class, on='Sku', how='left')

# %%
df_salesunit_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236532 entries, 0 to 236531
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            236532 non-null  int64
#  1   Sku             236532 non-null  object
#  2   Merged Sku_x    236508 non-null  object
#  3   Month           236532 non-null  object
#  4   Units           236532 non-null  float64
#  5   CHANNEL         236532 non-null  object
#  6   Sku #           204138 non-null  object
#  7   Classification  204138 non-null  object
#  8   Subclass        204138 non-null  object
#  9   Collection      204138 non-null  object
#  10  Merged Sku_y    204138 non-null  object
#  11  Launch Date     204138 non-null  object
#  12  COGS            204138 non-null  float64
#  13  MSRP            204138 non-null  float64
#  14  Line Edit       204138 non-null  object
#  15  Channel         204138 non-null  object
# ...

# %%
df_salesunit_combined.drop(columns=['Merged Sku_y', 'Channel', 'Region Code'], inplace=True)

# %%
df_salesunit_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236532 entries, 0 to 236531
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            236532 non-null  int64
#  1   Sku             236532 non-null  object
#  2   Merged Sku_x    236508 non-null  object
#  3   Month           236532 non-null  object
#  4   Units           236532 non-null  float64
#  5   CHANNEL         236532 non-null  object
#  6   Sku #           204138 non-null  object
#  7   Classification  204138 non-null  object
#  8   Subclass        204138 non-null  object
#  9   Collection      204138 non-null  object
#  10  Launch Date     204138 non-null  object
#  11  COGS            204138 non-null  float64
#  12  MSRP            204138 non-null  float64
#  13  Line Edit       204138 non-null  object
#  14  Region Name     204138 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 28.9+ MB

# %%
filt = (~(df_salesunit_combined['Sku #'].isna()) | (df_salesunit_combined['Units'] != 0))
df_salesunit_combined[filt]
# Out:
#         Year                        Sku               Merged Sku_x Month  \
# 12      2017  AGELESS-PLUMP-PROTECT-SET  AGELESS-PLUMP-PROTECT-SET   Jan
# 13      2017  AGELESS-PLUMP-PROTECT-SET  AGELESS-PLUMP-PROTECT-SET   Jan
# 14      2017  AGELESS-PLUMP-PROTECT-SET  AGELESS-PLUMP-PROTECT-SET   Jan
# 15      2017  AGELESS-PLUMP-PROTECT-SET  AGELESS-PLUMP-PROTECT-SET   Jan
# 16      2017  AGELESS-PLUMP-PROTECT-SET  AGELESS-PLUMP-PROTECT-SET   Jan
# ...      ...                        ...                        ...   ...
# 236527  2019                   DS-CREAM                   DS-CREAM   Dec
# 236528  2019                   DS-CREAM                   DS-CREAM   Dec
# 236529  2019                   DS-CREAM                   DS-CREAM   Dec
# 236530  2019                   DS-CREAM                   DS-CREAM   Dec
# 236531  2019                   DS-CREAM                   DS-CREAM   Dec
#
#         Units CHANNEL    Sku #       Classification     Subclass  \
# ...

# %%
# month_dict = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4, 'May':5, 'Jun':6, 'Jul':7, \
#               'Aug':8, 'Sep':9, 'Oct':10, 'Nov':11, 'Dec':12}
df_salesunit_combined['Month'] = pd.to_datetime(df_salesunit_combined['Month'], format='%b').dt.month

# %%
df_salesunit_combined['Record Date'] = pd.to_datetime(df_salesunit_combined[['Year', 'Month']].assign(DAY=1))

# %%
df_salesunit_combined
# Out:
#         Year               Sku Merged Sku_x  Month  Units CHANNEL  Sku #  \
# 0       2017  7-DAY-BETA-CARDS                   1    0.0       3    NaN
# 1       2017  7-DAY-BETA-CARDS                   2    0.0       3    NaN
# 2       2017  7-DAY-BETA-CARDS                   3    0.0       3    NaN
# 3       2017  7-DAY-BETA-CARDS                   4    0.0       3    NaN
# 4       2017  7-DAY-BETA-CARDS                   5    0.0       3    NaN
# ...      ...               ...          ...    ...    ...     ...    ...
# 236527  2019          DS-CREAM     DS-CREAM     12    0.0       8  Sku 3
# 236528  2019          DS-CREAM     DS-CREAM     12    0.0       8  Sku 3
# 236529  2019          DS-CREAM     DS-CREAM     12    0.0       8  Sku 3
# 236530  2019          DS-CREAM     DS-CREAM     12    0.0       8  Sku 3
# 236531  2019          DS-CREAM     DS-CREAM     12    0.0       8  Sku 3
#
#        Classification     Subclass Collection Launch Date  COGS  MSRP  \
# ...

# %%
df_salesunit_combined.rename(columns = {'Merged Sku_x':'Merged Sku'}, inplace = True)

# %%
df_salesunit_combined['Sku'][df_salesunit_combined['Sku'].str.contains('CHANNEL 3')]
# Out:
# 12684    CHANNEL 3-AGELESS-EYE-OTO-A283138
# 12685    CHANNEL 3-AGELESS-EYE-OTO-A283138
# 12686    CHANNEL 3-AGELESS-EYE-OTO-A283138
# 12687    CHANNEL 3-AGELESS-EYE-OTO-A283138
# 12688    CHANNEL 3-AGELESS-EYE-OTO-A283138
#                        ...
# 43039            CHANNEL 3-RED-LIP-A291363
# 43040            CHANNEL 3-RED-LIP-A291363
# 43041            CHANNEL 3-RED-LIP-A291363
# 43042            CHANNEL 3-RED-LIP-A291363
# 43043            CHANNEL 3-RED-LIP-A291363
# Name: Sku, Length: 3384, dtype: object

# %%
df_salesunit_combined['Sku'][df_salesunit_combined['Sku'].str.contains('CHANNEL 3')] = df_salesunit_combined['Sku'][df_salesunit_combined['Sku'].str.contains('CHANNEL 3')].apply(lambda x: str(x)[10:])
# Out:
# C:\Users\Subhrajit\AppData\Local\Temp\ipykernel_3564\4248883369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salesunit_combined['Sku'][df_salesunit_combined['Sku'].str.contains('CHANNEL 3')] = df_salesunit_combined['Sku'][df_salesunit_combined['Sku'].str.contains('CHANNEL 3')].apply(lambda x: str(x)[10:])

# %%
df_salesunit_combined['Merged Sku'][df_salesunit_combined['Merged Sku'].str.contains('CHANNEL 3', na=False)] = df_salesunit_combined['Merged Sku'][df_salesunit_combined['Merged Sku'].str.contains('CHANNEL 3', na=False)].apply(lambda x: str(x)[10:])
# Out:
# C:\Users\Subhrajit\AppData\Local\Temp\ipykernel_3564\170343152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salesunit_combined['Merged Sku'][df_salesunit_combined['Merged Sku'].str.contains('CHANNEL 3', na=False)] = df_salesunit_combined['Merged Sku'][df_salesunit_combined['Merged Sku'].str.contains('CHANNEL 3', na=False)].apply(lambda x: str(x)[10:])

# %%
df_salesunit_combined.head(100)
# Out:
#     Year               Sku     Merged Sku  Month  Units CHANNEL   Sku #  \
# 0   2017  7-DAY-BETA-CARDS                     1    0.0       3     NaN
# 1   2017  7-DAY-BETA-CARDS                     2    0.0       3     NaN
# 2   2017  7-DAY-BETA-CARDS                     3    0.0       3     NaN
# 3   2017  7-DAY-BETA-CARDS                     4    0.0       3     NaN
# 4   2017  7-DAY-BETA-CARDS                     5    0.0       3     NaN
# ..   ...               ...            ...    ...    ...     ...     ...
# 95  2017     BEAUTY-OIL-30  BEAUTY-OIL-30      2    0.0       3  Sku 33
# 96  2017     BEAUTY-OIL-30  BEAUTY-OIL-30      2    0.0       3  Sku 33
# 97  2017     BEAUTY-OIL-30  BEAUTY-OIL-30      2    0.0       3  Sku 33
# 98  2017     BEAUTY-OIL-30  BEAUTY-OIL-30      2    0.0       3  Sku 33
# 99  2017     BEAUTY-OIL-30  BEAUTY-OIL-30      2    0.0       3  Sku 33
#
#    Classification Subclass  Collection Launch Date      COGS  MSRP Line Edit  \
# ...

# %%
df_salesunit_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236532 entries, 0 to 236531
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            236532 non-null  int64
#  1   Sku             236532 non-null  object
#  2   Merged Sku      236508 non-null  object
#  3   Month           236532 non-null  int64
#  4   Units           236532 non-null  float64
#  5   CHANNEL         236532 non-null  object
#  6   Sku #           204138 non-null  object
#  7   Classification  204138 non-null  object
#  8   Subclass        204138 non-null  object
#  9   Collection      204138 non-null  object
#  10  Launch Date     204138 non-null  object
#  11  COGS            204138 non-null  float64
#  12  MSRP            204138 non-null  float64
#  13  Line Edit       204138 non-null  object
#  14  Region Name     204138 non-null  object
#  15  Record Date     236532 non-null  datetime64[ns]
# ...

# %%
df_salesunit_combined.columns
# Out:
# Index(['Year', 'Sku', 'Merged Sku', 'Month', 'Units', 'CHANNEL', 'Sku #',
#        'Classification', 'Subclass', 'Collection', 'Launch Date', 'COGS',
#        'MSRP', 'Line Edit', 'Region Name', 'Record Date'],
#       dtype='object')

# %%
df_salesunit_combined = df_salesunit_combined[['Year', 'Month', 'Record Date', 'Sku #','Sku', 'Merged Sku', 'Launch Date',
                      'Classification', 'Subclass', 'Collection', 'CHANNEL',
                      'Units', 'COGS', 'MSRP', 'Line Edit', 'Region Name']]

# %%
df_salesunit_combined.rename(columns = {'CHANNEL':'Channel'}, inplace = True)

# %%
# Excel-File
df_salesunit_combined.to_excel('Salesunit-Combined.xlsx', index=False)

# %%
df_allchsalesvol['Channel'] = df_allchsalesvol['Channel'].apply(lambda x: str(x)[8:])

# %%
df_allchsalesvol
# Out:
#        Year Channel               Sku Merged Sku Month  Volume Brand_Flag
# 0      2017       3  7-DAY-BETA-CARDS              Jan     0.0        ABC
# 1      2017       3  7-DAY-BETA-CARDS              Feb     0.0        ABC
# 2      2017       3  7-DAY-BETA-CARDS              Mar     0.0        ABC
# 3      2017       3  7-DAY-BETA-CARDS              Apr     0.0        ABC
# 4      2017       3  7-DAY-BETA-CARDS              May     0.0        ABC
# ...     ...     ...               ...        ...   ...     ...        ...
# 70406  2019       1         PEONY-LIP  PEONY-LIP   Aug     0.0        ABC
# 70407  2019       1         PEONY-LIP  PEONY-LIP   Sep     0.0        ABC
# 70408  2019       1         PEONY-LIP  PEONY-LIP   Oct     0.0        ABC
# 70409  2019       1         PEONY-LIP  PEONY-LIP   Nov     0.0        ABC
# 70410  2019       1         PEONY-LIP  PEONY-LIP   Dec     0.0        ABC
#
# [70411 rows x 7 columns]

# %%
df_allchsalesvol['Month'] = pd.to_datetime(df_allchsalesvol['Month'], format='%b').dt.month

# %%
df_allchsalesvol
# Out:
#        Year Channel               Sku Merged Sku  Month  Volume Brand_Flag
# 0      2017       3  7-DAY-BETA-CARDS                 1     0.0        ABC
# 1      2017       3  7-DAY-BETA-CARDS                 2     0.0        ABC
# 2      2017       3  7-DAY-BETA-CARDS                 3     0.0        ABC
# 3      2017       3  7-DAY-BETA-CARDS                 4     0.0        ABC
# 4      2017       3  7-DAY-BETA-CARDS                 5     0.0        ABC
# ...     ...     ...               ...        ...    ...     ...        ...
# 70406  2019       1         PEONY-LIP  PEONY-LIP      8     0.0        ABC
# 70407  2019       1         PEONY-LIP  PEONY-LIP      9     0.0        ABC
# 70408  2019       1         PEONY-LIP  PEONY-LIP     10     0.0        ABC
# 70409  2019       1         PEONY-LIP  PEONY-LIP     11     0.0        ABC
# 70410  2019       1         PEONY-LIP  PEONY-LIP     12     0.0        ABC
#
# [70411 rows x 7 columns]

# %%
df_allchsalesvol['Record Date'] = pd.to_datetime(df_allchsalesvol[['Year', 'Month']].assign(DAY=1))

# %%
df_allchsalesvol
# Out:
#        Year Channel               Sku Merged Sku  Month  Volume Brand_Flag  \
# 0      2017       3  7-DAY-BETA-CARDS                 1     0.0        ABC
# 1      2017       3  7-DAY-BETA-CARDS                 2     0.0        ABC
# 2      2017       3  7-DAY-BETA-CARDS                 3     0.0        ABC
# 3      2017       3  7-DAY-BETA-CARDS                 4     0.0        ABC
# 4      2017       3  7-DAY-BETA-CARDS                 5     0.0        ABC
# ...     ...     ...               ...        ...    ...     ...        ...
# 70406  2019       1         PEONY-LIP  PEONY-LIP      8     0.0        ABC
# 70407  2019       1         PEONY-LIP  PEONY-LIP      9     0.0        ABC
# 70408  2019       1         PEONY-LIP  PEONY-LIP     10     0.0        ABC
# 70409  2019       1         PEONY-LIP  PEONY-LIP     11     0.0        ABC
# 70410  2019       1         PEONY-LIP  PEONY-LIP     12     0.0        ABC
#
#       Record Date
# 0      2017-01-01
# 1      2017-02-01
# ...

# %%
df_salesvol_combined = df_allchsalesvol.merge(df_sku_cogs_class, on='Sku', how='left')

# %%
df_salesvol_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236415 entries, 0 to 236414
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            236415 non-null  int64
#  1   Channel_x       236415 non-null  object
#  2   Sku             236415 non-null  object
#  3   Merged Sku_x    236415 non-null  object
#  4   Month           236415 non-null  int64
#  5   Volume          236415 non-null  float64
#  6   Brand_Flag      236415 non-null  object
#  7   Record Date     236415 non-null  datetime64[ns]
#  8   Sku #           204025 non-null  object
#  9   Classification  204025 non-null  object
#  10  Subclass        204025 non-null  object
#  11  Collection      204025 non-null  object
#  12  Merged Sku_y    204025 non-null  object
#  13  Launch Date     204025 non-null  object
#  14  COGS            204025 non-null  float64
#  15  MSRP            204025 non-null  float64
# ...

# %%
df_salesvol_combined.sample(10)
# Delete Region Code, Merged_Sku_y, Channel_y
# Out:
#         Year Channel_x                  Sku         Merged Sku_x  Month  \
# 52579   2017         1        CL-TOUMEI-DUO        CL-TOUMEI-DUO      6
# 26617   2017         4     SKIN-MIST-TRAVEL  SKIN-MIST-TRAVEL-V2      6
# 145456  2018         1            INDG-HAND            INDG-HAND      7
# 20554   2017         4            INDG-BODY            INDG-BODY      7
# 98287   2018         2    BEAUTY-OIL-TRAVEL    BEAUTY-OIL-TRAVEL      3
# 114374  2018         7           DRY-RITUAL           DRY-RITUAL     10
# 68783   2018         3            GT-POWDER            GT-POWDER      5
# 148431  2018         1    PARASOL-2016-CRTD    PARASOL-2016-CRTD      7
# 54434   2017         1  GOLD-HAND-MIRROR-XX                           6
# 183368  2019         4  INDG-FACE-CREAM-POD                           6
#
#         Volume Brand_Flag Record Date    Sku #       Classification  \
# 52579      0.0        ABC  2017-06-01  Sku 239  Limited Edition Set
# ...

# %%
df_salesvol_combined.drop(columns=['Channel_y', 'Region Code', 'Merged Sku_y'], inplace=True)

# %%
df_salesvol_combined.sample(10)
# Out:
#         Year Channel_x                       Sku              Merged Sku_x  \
# 193982  2019         7          DP-POWDER-TRAVEL       DP-POWDER-TRAVEL-V2
# 201925  2019         7     SENSITIVE-RITUAL-KIRI     SENSITIVE-RITUAL-KIRI
# 161718  2019         3            INDG-KYOTO-DUO            INDG-KYOTO-DUO
# 235199  2019         1            LUX-TRAVEL-SET            LUX-TRAVEL-SET
# 2022    2017         3                 DP-POWDER              DP-POWDER-V2
# 155089  2018         1       PINK-STARTER-RITUAL       PINK-STARTER-RITUAL
# 217227  2019         6              SPF35-TRAVEL              SPF35-TRAVEL
# 71981   2018         3          LIFT-MASK-4-COMP
# 151561  2018         1  SUPPLE-PLUMP-PROTECT-SET  SUPPLE-PLUMP-PROTECT-SET
# 125591  2018         6     BEAUTY-OIL-DELUXE-LOY
#
#         Month   Volume Brand_Flag Record Date    Sku #       Classification  \
# 193982      6      0.0        ABC  2019-06-01  Sku 244               Travel
# ...

# %%
df_salesvol_combined.rename(columns = {'Merged Sku_x':'Merged Sku', 'Channel_x':'Channel'}, inplace = True)

# %%
df_salesvol_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236415 entries, 0 to 236414
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            236415 non-null  int64
#  1   Channel         236415 non-null  object
#  2   Sku             236415 non-null  object
#  3   Merged Sku      236415 non-null  object
#  4   Month           236415 non-null  int64
#  5   Volume          236415 non-null  float64
#  6   Record Date     236415 non-null  datetime64[ns]
#  7   Sku #           204025 non-null  object
#  8   Classification  204025 non-null  object
#  9   Subclass        204025 non-null  object
#  10  Collection      204025 non-null  object
#  11  Launch Date     204025 non-null  object
#  12  COGS            204025 non-null  float64
#  13  MSRP            204025 non-null  float64
#  14  Line Edit       204025 non-null  object
#  15  Region Name     204025 non-null  object
# ...

# %%
df_salesvol_combined.drop(columns='Brand_Flag', inplace=True)

# %%
df_salesvol_combined.columns
# Out:
# Index(['Year', 'Channel', 'Sku', 'Merged Sku', 'Month', 'Volume',
#        'Record Date', 'Sku #', 'Classification', 'Subclass', 'Collection',
#        'Launch Date', 'COGS', 'MSRP', 'Line Edit', 'Region Name'],
#       dtype='object')

# %%
df_salesvol_combined = df_salesvol_combined[['Year', 'Month', 'Record Date', 'Sku #','Sku', 'Merged Sku', 'Launch Date',
                      'Classification', 'Subclass', 'Collection', 'Channel',
                      'Volume', 'COGS', 'MSRP', 'Line Edit', 'Region Name']]

# %%
df_salesvol_combined['Sku'][df_salesvol_combined['Sku'].str.contains('CHANNEL 3')] = df_salesvol_combined['Sku'][df_salesvol_combined['Sku'].str.contains('CHANNEL 3')].apply(lambda x: str(x)[10:])
# Out:
# C:\Users\Subhrajit\AppData\Local\Temp\ipykernel_3564\487783455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salesvol_combined['Sku'][df_salesvol_combined['Sku'].str.contains('CHANNEL 3')] = df_salesvol_combined['Sku'][df_salesvol_combined['Sku'].str.contains('CHANNEL 3')].apply(lambda x: str(x)[10:])
# C:\Users\Subhrajit\AppData\Local\Temp\ipykernel_3564\487783455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_salesvol_combined['Merged Sku'][df_salesvol_combined['Merged Sku'].str.contains('CHANNEL 3', na=False)] = df_salesvol_combined['Merged Sku'][df_salesvol_combined['Merged Sku'].str.contains('CHANNEL 3', na=False)].apply(lambda x: str(x)[10:])
# Out:
# C:\Users\Subhrajit\AppData\Local\Temp\ipykernel_3564\381786910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salesvol_combined['Merged Sku'][df_salesvol_combined['Merged Sku'].str.contains('CHANNEL 3', na=False)] = df_salesvol_combined['Merged Sku'][df_salesvol_combined['Merged Sku'].str.contains('CHANNEL 3', na=False)].apply(lambda x: str(x)[10:])
# C:\Users\Subhrajit\AppData\Local\Temp\ipykernel_3564\381786910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Excel-File
df_salesvol_combined.to_excel('Salesvol-Combined.xlsx', index=False)
